# %%
from pathlib import Path 
import sys

sys.path.append(str(Path.cwd().parent))

from services.job_search_service import search_jobs_by_queries, get_job_search_queries
from services.job_extraction_service import scrape_raw_job_content

# %%
queries = get_job_search_queries()
