# %%
from pathlib import Path 
import sys

sys.path.append(str(Path.cwd().parent))

from helpers.job_utils import get_month_windows

from datetime import datetime

# %%
get_month_windows(datetime.now())
# Out:
# [('2026-09-12', '2026-09-22'),
#  ('2026-09-02', '2026-09-12'),
#  ('2026-08-23', '2026-09-02')]

# %%
get_month_windows
